# %%
import csv
import bmt
import requests
import linkml
from linkml_runtime import SchemaView
from collections import defaultdict
from typing import Tuple, List
import requests
import yaml
from pprint import pprint
from biothings_explorer.smartapi_kg.dataload import load_specs
import pandas
import json

tk = bmt.Toolkit('https://raw.githubusercontent.com/biolink/biolink-model/2.2.12/biolink-model.yaml')
tsv_file = open("predicates.tsv", "w")
tsv_attributes = open("attributes.tsv", "w")
tsv_writer = csv.writer(tsv_file, delimiter='\t')
tsv_writer_att = csv.writer(tsv_attributes, delimiter='\t')

# %%
def sample_predicates():
    specs = load_specs()
    kp_titles = []
    for spec in specs:
        if 'x-translator' not in spec['info']:
            continue
        if spec['info']['x-translator']['component'] == 'KP':
            kp_titles.append(spec['info']['title'])
        if 'servers' not in spec:
            continue
        else:
            url = spec['servers'][0]['url']
            apititle = '_'.join(spec['info']['title'].split())
            if url.endswith('/'):
                url = url[:-1]
            predicates_url = f'{url}/meta_knowledge_graph'
            print(predicates_url)
            trapi, predicates = get_predicates(predicates_url)
            # if is_trapi:
            if not predicates:
                continue
            else:
                print("got predicates")
                preds, attribs, url = dump_trapi_predicate_results(predicates, predicates_url)
                predicates = set(preds)
                attributes = set(attribs)
                for pred in predicates:
                    tsv_writer.writerow([apititle, url, pred])
                for attrib in attributes:
                    tsv_writer_att.writerow([apititle, url, attrib])
            # else:
            #     dump_smartapi_predicate_results(spec['info']['title'])

# %%
def in_biolink_model(predicate):
    is_predicate = tk.is_predicate(predicate)
    return is_predicate

# %%
def dump_trapi_predicate_results(predicates, url):
    preds = []
    attribs = []
    for edge in predicates.get('edges'):
        predicate = edge.get('predicate')
        subject = edge.get('subject')
        tobject = edge.get('object')
        if 'attributes' in edge and edge.get('attributes') is not None:
            for attribute in edge.get('attributes'):
                attribs.append(attribute.get('attribute_type_id'))
        preds.append(predicate)
    return preds, attribs, url

            # tsv_writer.writerow([subject, predicate, tobject, url])

# %%
def get_predicates(pr_url):
    try:
        response = requests.get(pr_url)
        if response.status_code == 200:
            return True, response.json()
        else:
            return False, {}
    except:
        return False, {}

# %%
if __name__ == '__main__':
    sample_predicates()
# Out:
# /socio_environmental_exposures_api/v1/meta_knowledge_graph
# /cmaq_exposures_api/v1/meta_knowledge_graph
# /roadway_proximity_api/v1/meta_knowledge_graph
# https://name-resolution-sri.renci.org/meta_knowledge_graph
# https://icees-pcd.renci.org/meta_knowledge_graph
# got predicates
# https://icees-dili-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/proteins/api/meta_knowledge_graph
# https://icees-asthma-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://icees-asthma.renci.org/meta_knowledge_graph
# got predicates
# https://translator-workflow-runner.renci.org/meta_knowledge_graph
# https://icees-pcd-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/ols/api/meta_knowledge_graph
# https://www.ncbi.nlm.nih.gov/research/bionlp/litvar/api/v1/meta_knowledge_graph
# https://icees-dili.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/QuickGO/services/meta_knowledge_graph
# https://ontology-kp.apps.renci.org/meta_knowledge_graph
# got predicates
# https://trapi.monarchinitiative.org/1.2/meta_knowledge_graph
# got predicates
# https://medikanren-trapi.ci.transltr.io/v2/meta_knowledge_graph
# https://automat.renci.org/gtex/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/intact/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/gtopdb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/drugcentral/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/chemical-normalization/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/ctd/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/cord19/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/panther/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/textminingkp/1.2/meta_knowledge_graph
# got predicates
# https://bl-lookup-sri.renci.org/meta_knowledge_graph
# https://automat.renci.org/hmdb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/covidkopkg/1.2/meta_knowledge_graph
# got predicates
# https://nodenormalization-sri.renci.org/1.2/meta_knowledge_graph
# https://nodenormalization-dev.apps.renci.org/1.2/meta_knowledge_graph
# https://automat.renci.org/pharos/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/human-goa/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/uberongraph/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/biolink/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/viral-proteome/1.2/meta_knowledge_graph
# got predicates
# https://cam-kp-api.renci.org/1.2.0/meta_knowledge_graph
# got predicates
# https://automat.renci.org/hgnc/1.2/meta_knowledge_graph
# got predicates
# https://cam-kp-api.renci.org/1.2.0/meta_knowledge_graph
# got predicates
# https://automat.renci.org/robokopkg/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/ontological-hierarchy/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/foodb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/gwas-catalog/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/molepro-fda/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/hetio/1.2/meta_knowledge_graph
# got predicates
# https://explanatory-agent.azurewebsites.net/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/uberon/meta_knowledge_graph
# https://aragorn-dev.apps.renci.org/1.2/meta_knowledge_graph
# http://chp.thayer.dartmouth.edu/meta_knowledge_graph
# got predicates
# https://smart-api.info/api/meta_knowledge_graph
# https://biothings.ncats.io/hpo/meta_knowledge_graph
# https://aragorn.renci.org/1.2/meta_knowledge_graph
# https://cooccurrence-p36smkc6hq-uc.a.run.app/meta_knowledge_graph
# got predicates
# https://spokekp.healthdatascience.cloud/api/v1.2/meta_knowledge_graph
# got predicates
# https://cohd.io/api/meta_knowledge_graph
# got predicates
# https://openpredict.semanticscience.org/meta_knowledge_graph
# got predicates
# https://mygene.info/v3/meta_knowledge_graph
# https://myvariant.info/v1/meta_knowledge_graph
# https://biothings.ncats.io/rhea/meta_knowledge_graph
# https://molepro-trapi.transltr.io/molepro/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://ia.healthdatascience.cloud/api/v1.2/meta_knowledge_graph
# got predicates
# http://mydisease.info/v1/meta_knowledge_graph
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/DISEASES/meta_knowledge_graph
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/mgigene2phenotype/meta_knowledge_graph
# https://mychem.info/v1/meta_knowledge_graph
# https://biothings.ncats.io/ebigene2phenotype/meta_knowledge_graph
# https://biothings.ncats.io/go_bp/meta_knowledge_graph
# https://arax.ncats.io/beta/api/rtxkg2/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/go_cc/meta_knowledge_graph
# https://arax.ncats.io/api/rtxkg2/v1.2/meta_knowledge_graph
# got predicates
# https://api.bte.ncats.io/v1/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/idisk/meta_knowledge_graph
# https://biothings.ncats.io/go_mf/meta_knowledge_graph
# https://api.bte.ncats.io/v1/team/Service%20Provider/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/multiomics_wellness_kp/meta_knowledge_graph
# https://api.collaboratory.semanticscience.org/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/dgidb/meta_knowledge_graph
# https://biothings.ncats.io/semmeddb/meta_knowledge_graph
# https://biothings.ncats.io/drug_response_kp/meta_knowledge_graph
# https://api.monarchinitiative.org/api/meta_knowledge_graph
# https://biothings.ncats.io/text_mining_targeted_association/meta_knowledge_graph
# https://arax.ncats.io/api/arax/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/clinical_risk_kp/meta_knowledge_graph
# https://arax.ncats.io/beta/api/arax/v1.2/meta_knowledge_graph
# got predicates

# %%
sv = SchemaView('https://raw.githubusercontent.com/biolink/biolink-model/master/biolink-model.yaml')

# %%
with open('output.tsv', 'w', newline='') as f_output:
    tsv_output = csv.writer(f_output, delimiter='\t')

    for s in sv.all_slots().values():
        rows = []
        if 'related to' in sv.slot_ancestors(s.name):
            rows.append(s.name)
            for x in sv.slot_children(s.name):
                rows.append(x)

            tsv_output.writerow(rows)
            # else:
            rows = []

# %%
for s in sv.all_slots().values():
    if 'related to' in sv.slot_ancestors(s.name):
        rows.append(s.name)
        for child in sv.slot_children(s.name):

# %%
def load_predicate_tree_data(biolink_version: str) -> Tuple[List[dict], str]:
    # Grab Biolink yaml file and load into dictionary tree structures
    response = requests.get(f"https://raw.githubusercontent.com/biolink/biolink-model/"
                            f"{biolink_version if biolink_version else 'master'}/biolink-model.yaml",
                            timeout=10)
    if response.status_code == 200:
        # Build predicates tree
        biolink_model = yaml.safe_load(response.text)
        parent_to_child_dict = defaultdict(set)
        for slot_name_english, info in biolink_model["slots"].items():
            slot_name = convert_predicate_to_trapi_format(slot_name_english)
            parent_name_english = info.get("is_a")
            if parent_name_english:
                parent_name = convert_predicate_to_trapi_format(parent_name_english)
                parent_to_child_dict[parent_name].add(slot_name)
        root_node = {"name": "related_to"}
        predicate_tree = get_tree_node_recursive(root_node, parent_to_child_dict)
        biolink_version = biolink_model["version"]
        return [predicate_tree], biolink_version
    else:
        return [], ""

# %%
def get_tree_node_recursive(root_node: dict, parent_to_child_map: dict):
    root_name = root_node["name"]
    children_predicates = parent_to_child_map.get(root_name, [])
    if children_predicates:
        children = []
        for child_predicate in children_predicates:
            child_node = {"name": child_predicate, "parent": root_name}
            child_node = get_tree_node_recursive(child_node, parent_to_child_map)
            children.append(child_node)
        root_node["children"] = sorted(children, key=lambda x: x["name"])
    return root_node

# %%
with open('test.txt', 'a') as f:
    row = []
    ptd = load_predicate_tree_data("master")
    for item in ptd[0]:
        f.write(item["name"] + ",,,,," + "\n")
        row.append(item["name"])
        if item.get("children"):
            for child in item['children']:
                f.write("," + child['name'] + ",,,," + "\n")
                row.append(child['name'])
                if child.get("children"):
                    for gchild in child['children']:
                        f.write(",," + gchild['name'] + ",,," + "\n")
                        row.append(gchild['name'])
                        if gchild.get("children"):
                            for ggchild in gchild['children']:
                                f.write(",,," + ggchild['name'] + ",," + "\n")
                                row.append(ggchild['name'])
                                if ggchild.get("children"):
                                    for gggchild in ggchild['children']:
                                        f.write(",,,," + gggchild['name'] + "," + "\n")
                                        row.append(gggchild['name'])
        pprint(row)
        rows = []
# Out:
# ['related_to',
#  'composed_primarily_of',
#  'disease_has_location',
#  'related_to_at_concept_level',
#  'broad_match',
#  'close_match',
#  'exact_match',
#  'same_as',
#  'narrow_match',
#  'subclass_of',
#  'superclass_of',
#  'related_to_at_instance_level',
#  'active_in',
#  'acts_upstream_of',
#  'acts_upstream_of_negative_effect',
#  'acts_upstream_of_or_within',
#  'acts_upstream_of_or_within_negative_effect',
#  'acts_upstream_of_or_within_positive_effect',
#  'acts_upstream_of_positive_effect',
#  'affected_by',
#  'abundance_affected_by',
#  'abundance_decreased_by',
#  'abundance_increased_by',
#  'activity_affected_by',
#  'activity_decreased_by',
#  'activity_increased_by',
#  'degradation_affected_by',
#  'degradation_decreased_by',
#  'degradation_increased_by',
#  'disrupted_by',
#  'entity_regulated_by_entity',
#  'entity_negatively_regulated_by_entity',
#  'entity_positively_regulated_by_entity',
#  'expression_affected_by',
#  'expression_decreased_by',
#  'expression_increased_by',
#  'folding_affected_by',
#  'folding_decreased_by',
#  'folding_increased_by',
#  'is_ameliorated_by',
#  'is_exacerbated_by',
#  'localization_affected_by',
#  'localization_decreased_by',
#  'localization_increased_by',
#  'metabolic_processing_affected_by',
#  'metabolic_processing_decreased_by',
#  'metabolic_processing_increased_by',
#  'molecular_modification_affected_by',
#  'molecular_modification_decreased_by',
#  'molecular_modification_increased_by',
#  'mutation_rate_affected_by',
#  'mutation_rate_decreased_by',
#  'mutation_rate_increased_by',
#  'process_regulated_by_process',
#  'process_negatively_regulated_by_process',
#  'process_positively_regulated_by_process',
#  'response_affected_by',
#  'response_decreased_by',
#  'response_increased_by',
#  'secretion_affected_by',
#  'secretion_decreased_by',
#  'secretion_increased_by',
#  'splicing_affected_by',
#  'splicing_decreased_by',
#  'splicing_increased_by',
#  'stability_affected_by',
#  'stability_decreased_by',
#  'stability_increased_by',
#  'synthesis_affected_by',
#  'synthesis_decreased_by',
#  'synthesis_increased_by',
#  'transport_affected_by',
#  'transport_decreased_by',
#  'transport_increased_by',
#  'uptake_affected_by',
#  'uptake_decreased_by',
#  'uptake_increased_by',
#  'affects',
#  'affects_abundance_of',
#  'decreases_abundance_of',
#  'increases_abundance_of',
#  'affects_activity_of',
#  'decreases_activity_of',
#  'increases_activity_of',
#  'affects_degradation_of',
#  'decreases_degradation_of',
#  'increases_degradation_of',
#  'affects_expression_in',
#  'affects_expression_of',
#  'decreases_expression_of',
#  'increases_expression_of',
#  'affects_folding_of',
#  'decreases_folding_of',
#  'increases_folding_of',
#  'affects_localization_of',
#  'decreases_localization_of',
#  'increases_localization_of',
#  'affects_metabolic_processing_of',
#  'decreases_metabolic_processing_of',
#  'increases_metabolic_processing_of',
#  'affects_molecular_modification_of',
#  'decreases_molecular_modification_of',
#  'increases_molecular_modification_of',
#  'affects_mutation_rate_of',
#  'decreases_mutation_rate_of',
#  'increases_mutation_rate_of',
#  'affects_response_to',
#  'decreases_response_to',
#  'increases_response_to',
#  'affects_secretion_of',
#  'decreases_secretion_of',
#  'increases_secretion_of',
#  'affects_splicing_of',
#  'decreases_splicing_of',
#  'increases_splicing_of',
#  'affects_stability_of',
#  'decreases_stability_of',
#  'increases_stability_of',
#  'affects_synthesis_of',
#  'decreases_synthesis_of',
#  'increases_synthesis_of',
#  'affects_transport_of',
#  'decreases_transport_of',
#  'increases_transport_of',
#  'affects_uptake_of',
#  'decreases_uptake_of',
#  'increases_uptake_of',
#  'ameliorates',
#  'treats',
#  'disrupts',
#  'entity_regulates_entity',
#  'entity_negatively_regulates_entity',
#  'entity_positively_regulates_entity',
#  'exacerbates',
#  'process_regulates_process',
#  'process_negatively_regulates_process',
#  'process_positively_regulates_process',
#  'affects_risk_for',
#  'predisposes',
#  'prevents',
#  'associated_with',
#  'associated_with_resistance_to',
#  'associated_with_sensitivity_to',
#  'correlated_with',
#  'biomarker_for',
#  'coexpressed_with',
#  'has_biomarker',
#  'negatively_correlated_with',
#  'occurs_together_in_literature_with',
#  'positively_correlated_with',
#  'resistance_associated_with',
#  'sensitivity_associated_with',
#  'caused_by',
#  'coexists_with',
#  'colocalizes_with',
#  'in_cell_population_with',
#  'in_complex_with',
#  'in_pathway_with',
#  'completed_by',
#  'contains_process',
#  'contraindicated_for',
#  'contributes_to',
#  'causes',
#  'adverse_event_caused_by',
#  'causes_adverse_event',
#  'contribution_from',
#  'contributor',
#  'author',
#  'editor',
#  'provider',
#  'publisher',
#  'decreased_amount_in',
#  'decreases_amount_or_activity_of',
#  'derives_from',
#  'is_metabolite_of',
#  'derives_into',
#  'has_metabolite',
#  'develops_from',
#  'develops_into',
#  'diagnoses',
#  'disease_has_basis_in',
#  'gene_product_of',
#  'genetic_association',
#  'condition_associated_with_gene',
#  'gene_associated_with_condition',
#  'has_completed',
#  'has_contraindication',
#  'has_contributor',
#  'has_author',
#  'has_editor',
#  'has_provider',
#  'has_publisher',
#  'has_decreased_amount',
#  'has_gene_product',
#  'has_increased_amount',
#  'has_manifestation',
#  'has_molecular_consequence',
#  'has_not_completed',
#  'has_participant',
#  'actively_involves',
#  'has_capability',
#  'enabled_by',
#  'has_catalyst',
#  'has_input',
#  'consumes',
#  'has_output',
#  'has_substrate',
#  'has_phenotype',
#  'has_real_world_evidence_of_association_with',
#  'has_sequence_location',
#  'has_sequence_variant',
#  'has_frameshift_variant',
#  'has_missense_variant',
#  'has_nearby_variant',
#  'has_non_coding_variant',
#  'has_nonsense_variant',
#  'has_splice_site_variant',
#  'has_synonymous_variant',
#  'has_target',
#  'has_upstream_actor',
#  'has_negative_upstream_actor',
#  'has_positive_upstream_actor',
#  'has_upstream_or_within_actor',
#  'has_negative_upstream_or_within_actor',
#  'has_positive_upstream_or_within_actor',
#  'in_linkage_disequilibrium_with',
#  'in_taxon',
#  'increased_amount_of',
#  'increases_amount_or_activity_of',
#  'interacts_with',
#  'directly_interacts_with',
#  'genetically_interacts_with',
#  'physically_interacts_with',
#  'chemically_interacts_with',
#  'molecularly_interacts_with',
#  'is_diagnosed_by',
#  'is_molecular_consequence_of',
#  'is_sequence_variant_of',
#  'is_frameshift_variant_of',
#  'is_missense_variant_of',
#  'is_nearby_variant_of',
#  'is_non_coding_variant_of',
#  'is_nonsense_variant_of',
#  'is_splice_site_variant_of',
#  'is_synonymous_variant_of',
#  'lacks_part',
#  'located_in',
#  'expressed_in',
#  'location_of',
#  'expresses',
#  'manifestation_of',
#  'mentioned_by',
#  'mentions',
#  'missing_from',
#  'model_of',
#  'models',
#  'not_completed_by',
#  'occurs_in',
#  'occurs_in_disease',
#  'opposite_of',
#  'overlaps',
#  'has_part',
#  'has_active_ingredient',
#  'has_excipient',
#  'has_food_component',
#  'has_plasma_membrane_part',
#  'has_variant_part',
#  'part_of',
#  'food_component_of',
#  'is_active_ingredient_of',
#  'is_excipient_of',
#  'plasma_membrane_part_of',
#  'variant_part_of',
#  'participates_in',
#  'actively_involved_in',
#  'capable_of',
#  'catalyzes',
#  'enables',
#  'is_input_of',
#  'consumed_by',
#  'is_output_of',
#  'is_substrate_of',
#  'phenotype_of',
#  'produced_by',
#  'produces',
#  'related_condition',
#  'risk_affected_by',
#  'prevented_by',
#  'sequence_location_of',
#  'similar_to',
#  'chemically_similar_to',
#  'homologous_to',
#  'orthologous_to',
#  'paralogous_to',
#  'xenologous_to',
#  'target_for',
#  'taxon_of',
#  'temporally_related_to',
#  'preceded_by',
#  'precedes',
#  'transcribed_from',
#  'transcribed_to',
#  'translates_to',
#  'translation_of',
#  'treated_by',
#  'approved_for_treatment_by']

# %%
def convert_predicate_to_trapi_format(english_predicate: str) -> str:
    # Converts a string like "treated by" to "treated_by"
    return english_predicate.replace(' ', '_')
